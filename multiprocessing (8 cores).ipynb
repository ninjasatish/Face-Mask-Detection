# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split



# Define dataset path
data_dir = "./dataset"
categories = ["with_mask", "without_mask"]

data = []
labels = []

for category in categories:
    path = os.path.join(data_dir, category)
    class_label = categories.index(category)

    for img_name in os.listdir(path):
        try:
            img_path = os.path.join(path, img_name)

            # Check if the file is an image
            if not img_path.lower().endswith((".png", ".jpg", ".jpeg")):
                print(f"Skipping non-image file: {img_name}")
                continue

            # print(f"Trying to read: {img_path}")
            img = cv2.imread(img_path)

            # if img is None:
            #     print(f"Failed to load: {img_path}")
            #     continue  # Skip unreadable images


            img = cv2.imread(img_path)

            # Check if the image was loaded successfully
            if img is None:
                print(f"Skipping unreadable image: {img_name}")
                continue

            img = cv2.resize(img, (64, 64))  # Resize to match CNN input
            data.append(img)
            labels.append(class_label)

        except Exception as e:
            print(f"Error loading image {img_name}: {e}")

# Convert to NumPy arrays
data = np.array(data) / 255.0  # Normalize pixel values
labels = np.array(labels)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)

print("Dataset successfully loaded!")
print(f"Total images loaded: {len(data)}")
# Out:
# 2025-04-20 22:18:51.571809: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-20 22:18:51.572762: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-20 22:18:51.576988: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-20 22:18:51.586865: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745167731.605455   79673 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745167731.611067   79673 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745167731.624815   79673 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745167731.624839   79673 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745167731.624841   79673 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745167731.624843   79673 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-20 22:18:51.629323: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Dataset successfully loaded!
# Total images loaded: 3832

# %%
import psutil
import threading
import time
import matplotlib.pyplot as plt

cpu_data = []  # List of lists: Each sublist is one sample across all cores
monitoring = True

def monitor_all_cores():
    while monitoring:
        usage = psutil.cpu_percent(interval=1, percpu=True)
        cpu_data.append(usage)

# Start background monitoring
monitor_thread = threading.Thread(target=monitor_all_cores)
monitor_thread.start()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# ─── Set thread parallelism BEFORE any TF operation ─────────────────────────────
tf.config.threading.set_intra_op_parallelism_threads(8)
tf.config.threading.set_inter_op_parallelism_threads(8)

# ─── Model definition ─────────────────────────────────────────────────────────
model = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(64, 64, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation="relu"),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(2, activation="softmax")   # Two classes
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /home/ashish/Downloads/Face-Mask-Detection-master/myenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-04-20 22:19:04.251499: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 62, 62, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       589,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 683,458 (2.61 MB)
#  Trainable params: 683,458 (2.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ─── Train ──────────────────────────────────────────────────────────────────────
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32
)

# Stop monitoring
monitoring = False
monitor_thread.join()

# Transpose the list to get usage per core
cpu_data = list(map(list, zip(*cpu_data)))  # Transpose

# Plot
plt.figure(figsize=(12, 6))
for i, core_usage in enumerate(cpu_data):
    plt.plot(core_usage, label=f'Core {i}')
plt.xlabel('Time (seconds)')
plt.ylabel('CPU Utilization (%)')
plt.title('Per-Core CPU Usage During Training')
plt.legend(loc='upper right', ncol=2)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.7676 - loss: 0.4487 - val_accuracy: 0.9153 - val_loss: 0.2105
# Epoch 2/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9200 - loss: 0.2160 - val_accuracy: 0.9505 - val_loss: 0.1506
# Epoch 3/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9461 - loss: 0.1764 - val_accuracy: 0.9478 - val_loss: 0.1435
# Epoch 4/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9503 - loss: 0.1353 - val_accuracy: 0.9596 - val_loss: 0.1129
# Epoch 5/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9580 - loss: 0.1128 - val_accuracy: 0.9400 - val_loss: 0.1720
# Epoch 6/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9598 - loss: 0.1211 - val_accuracy: 0.9648 - val_loss: 0.1086
# Epoch 7/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9675 - loss: 0.0878 - val_accuracy: 0.9661 - val_loss: 0.0964
# Epoch 8/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9645 - loss: 0.0911 - val_accuracy: 0.9700 - val_loss: 0.0899
# Epoch 9/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9793 - loss: 0.0666 - val_accuracy: 0.9791 - val_loss: 0.0680
# Epoch 10/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9833 - loss: 0.0491 - val_accuracy: 0.9452 - val_loss: 0.1743
# Epoch 11/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9666 - loss: 0.0880 - val_accuracy: 0.9674 - val_loss: 0.0890
# Epoch 12/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9866 - loss: 0.0473 - val_accuracy: 0.9609 - val_loss: 0.1391
# Epoch 13/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9803 - loss: 0.0560 - val_accuracy: 0.9739 - val_loss: 0.0808
# Epoch 14/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9858 - loss: 0.0460 - val_accuracy: 0.9778 - val_loss: 0.0738
# Epoch 15/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9895 - loss: 0.0357 - val_accuracy: 0.9765 - val_loss: 0.0739
# Epoch 16/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9918 - loss: 0.0233 - val_accuracy: 0.9739 - val_loss: 0.1013
# Epoch 17/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9974 - loss: 0.0114 - val_accuracy: 0.9857 - val_loss: 0.0627
# Epoch 18/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9952 - loss: 0.0184 - val_accuracy: 0.9844 - val_loss: 0.0646
# Epoch 19/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9961 - loss: 0.0124 - val_accuracy: 0.9831 - val_loss: 0.0823
# Epoch 20/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9880 - loss: 0.0364 - val_accuracy: 0.9817 - val_loss: 0.0675
# Epoch 21/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9962 - loss: 0.0099 - val_accuracy: 0.9752 - val_loss: 0.0892
# Epoch 22/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9970 - loss: 0.0103 - val_accuracy: 0.9857 - val_loss: 0.0733
# Epoch 23/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9976 - loss: 0.0092 - val_accuracy: 0.9817 - val_loss: 0.0839
# Epoch 24/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9804 - val_loss: 0.0916
# Epoch 25/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9944 - loss: 0.0130 - val_accuracy: 0.9674 - val_loss: 0.1354
# Epoch 26/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9875 - loss: 0.0434 - val_accuracy: 0.9635 - val_loss: 0.1812
# Epoch 27/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9744 - loss: 0.0776 - val_accuracy: 0.9870 - val_loss: 0.0628
# Epoch 28/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9975 - loss: 0.0089 - val_accuracy: 0.9817 - val_loss: 0.0662
# Epoch 29/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9979 - loss: 0.0044 - val_accuracy: 0.9791 - val_loss: 0.1069
# Epoch 30/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9946 - loss: 0.0180 - val_accuracy: 0.9817 - val_loss: 0.0742
# Epoch 31/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9989 - loss: 0.0065 - val_accuracy: 0.9804 - val_loss: 0.0943
# Epoch 32/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9945 - loss: 0.0187 - val_accuracy: 0.9844 - val_loss: 0.0998
# Epoch 33/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9977 - loss: 0.0088 - val_accuracy: 0.9831 - val_loss: 0.0985
# Epoch 34/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9968 - loss: 0.0074 - val_accuracy: 0.9817 - val_loss: 0.0880
# Epoch 35/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9968 - loss: 0.0161 - val_accuracy: 0.9765 - val_loss: 0.1321
# Epoch 36/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9765 - val_loss: 0.1099
# Epoch 37/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9951 - loss: 0.0096 - val_accuracy: 0.9791 - val_loss: 0.1229
# Epoch 38/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 0.9791 - val_loss: 0.1193
# Epoch 39/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 8.9395e-04 - val_accuracy: 0.9817 - val_loss: 0.1142
# Epoch 40/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 2.3171e-04 - val_accuracy: 0.9817 - val_loss: 0.1158
# Epoch 41/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 6.2346e-04 - val_accuracy: 0.9804 - val_loss: 0.1075
# Epoch 42/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 1.0000 - loss: 2.3863e-04 - val_accuracy: 0.9804 - val_loss: 0.1091
# Epoch 43/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 1.4149e-04 - val_accuracy: 0.9844 - val_loss: 0.1122
# Epoch 44/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 1.0000 - loss: 2.1108e-04 - val_accuracy: 0.9791 - val_loss: 0.1206
# Epoch 45/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 1.0000 - loss: 6.0489e-04 - val_accuracy: 0.9804 - val_loss: 0.1207
# Epoch 46/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 9.1159e-05 - val_accuracy: 0.9804 - val_loss: 0.1200
# Epoch 47/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 7.5433e-05 - val_accuracy: 0.9804 - val_loss: 0.1145
# Epoch 48/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 1.4580e-04 - val_accuracy: 0.9831 - val_loss: 0.1141
# Epoch 49/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 1.0000 - loss: 3.3700e-05 - val_accuracy: 0.9817 - val_loss: 0.1176
# Epoch 50/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 1.0000 - loss: 7.1802e-05 - val_accuracy: 0.9831 - val_loss: 0.1210

# %%
# ─── Save ───────────────────────────────────────────────────────────────────────
model.save("mask_detector_model.h5")
print("Model training complete and saved to mask_detector_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training complete and saved to mask_detector_model.h5
